# %%
i = 0
j = 1

phi = 1.618033989

for n in range(20):
    print("\tn = ", n)
    print("f(n)", (phi**n)*1.17)
    print("actual", i+j)
    i, j = j, i+j
    print("ratio", (phi**n)*1.17/ j)

print((5**.5 + 1)/2)

# f(n)/f(n+1) ~= phi - 1
# f(n+1) = f(n) + f(n-1)
# f(n-1) = f(n-2) + f(n-3)

# r^n = r^n-1 + r^n-2
# Out:
# 	n =  0
# f(n) 1.17
# actual 1
# ratio 1.17
# 	n =  1
# f(n) 1.8930997671299998
# actual 2
# ratio 0.9465498835649999
# 	n =  2
# f(n) 3.0630997677843244
# actual 3
# ratio 1.0210332559281081
# 	n =  3
# f(n) 4.9561995359730435
# actual 5
# ratio 0.9912399071946087
# 	n =  4
# f(n) 8.019299305470414
# actual 8
# ratio 1.0024124131838017
# 	n =  5
# f(n) 12.975498844215222
# actual 13
# ratio 0.9981152957088633
# 	n =  6
# f(n) 20.994798154170443
# actual 21
# ratio 0.9997522930557354
# 	n =  7
# f(n) 33.97029700564224
# actual 34
# ratio 0.9991263825188893
# 	n =  8
# f(n) 54.965095171554076
# actual 55
# ratio 0.9993653667555287
# 	n =  9
# f(n) 88.93539219619427
# actual 89
# ratio 0.9992740696201604
# 	n =  10
# f(n) 143.90048739848768
# actual 144
# ratio 0.9993089402672756
# 	n =  11
# f(n) 232.83587964441924
# actual 233
# ratio 0.9992956207914989
# 	n =  12
# f(n) 376.73636712338356
# actual 377
# ratio 0.999300708550089
# 	n =  13
# f(n) 609.5722468980167
# actual 610
# ...
